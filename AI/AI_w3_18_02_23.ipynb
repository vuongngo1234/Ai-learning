# %%
# load library
import pandas as pd
dataframe = pd.DataFrame()
#data frame
dataframe['name'] = ['lemon', 'apple', 'banana']
dataframe['price'] = [5,8,7]
dataframe['License'] = [False, True, True]
#show data
dataframe
# Out:
#      name  price  License
# 0   lemon      5    False
# 1   apple      8     True
# 2  banana      7     True

# %%
dataframe.loc[(dataframe.price == 5)| (dataframe.name == 'banana')]
# Out:
#      name  price  License
# 0   lemon      5    False
# 2  banana      7     True

# %%
# Out:
# pandas.core.indexing._iLocIndexer

# %%
dataframe.loc[(df.Price == 5)| (dataframe.Name == 'Banana'), ['Name','Price']]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
dataframe.iloc[2]
type(dataframe.iloc[2])
# Out:
# pandas.core.series.Series

# %%
dataframe.iloc[[2]]
# Out:
#      name  price  License
# 2  banana      7     True

# %%
dataframe.iloc[0:2]
# Out:
#     name  price  License
# 0  lemon      5    False
# 1  apple      8     True

# %%
dataframe.iloc[0:2,0:-1]
dataframe.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum = dataframe.price.sum()
  
print(sum)
# Out:
# 20

# %%
max = dataframe.price.max()
print(max)
# Out:
# 8

# %%
count = dataframe['price'].count()
print(count)
# Out:
# 3

# %%
# create row data
new = pd.Series(['orange',10,True], index=['name','price','license'])
# append row
dataframe.append(new, ignore_index=True)
# Out:
#      name  price  License  license
# 0   lemon      5      0.0      NaN
# 1   apple      8      1.0      NaN
# 2  banana      7      1.0      NaN
# 3  orange     10      NaN      1.0

# %%
# append a column
dataframe['Location'] = ['USA','VN','SIN']
dataframe
# Out:
#      name  price  License Location
# 0   lemon      5    False      USA
# 1   apple      8     True       VN
# 2  banana      7     True      SIN

# %%
# delete a row
dataframe.drop(1, axis=0).head(10)
# Out:
#      name  price  License Location
# 0   lemon      5    False      USA
# 2  banana      7     True      SIN

# %%
# delete a column
dataframe.drop('Location', axis=1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
# replace
dataframe['price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    8
# 2    7
# Name: price, dtype: int64

# %%
# rename columns
dataframe.rename(columns={'price':'cost'}).head()
# Out:
#      name  cost  License Location
# 0   lemon     5    False      USA
# 1   apple     8     True       VN
# 2  banana     7     True      SIN

# %%
# 2. KNOWING DATA

# %%
# load library
import pandas as pd
# create url
url = 'http://winterolympicsmedals.com/medals.csv'
# load data
dataframe = pd.read_csv(url)
# show data
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
data = dataframe
data.shape
# Out:
# (2311, 8)

# %%
data.describe()
# std: phuong sai
# mean: gia tri trung binh
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
data.iloc[0:10] # ~[:10]
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...
