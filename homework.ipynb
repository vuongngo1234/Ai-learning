# %% [markdown]
# <a href="https://colab.research.google.com/github/vuongngo1234/Ai-learning/blob/main/homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=8f770fe6b401d2bf0a07ac8fadbc5c4660714d221c2d451f893d32238fcd37f3
#   Stored in directory: /root/.cache/pip/wheels/32/2c/a1/a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

fever = ctrl.Antecedent(np.arange(0.1,1,0.1),'fever')
headache = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'headache')
nausea = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'nausea')
vomiting = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'vomiting')
jaundice = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'jaundice')
enlarge_liver = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'enlarge_liver')
joint_pain = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'joint_pain')
body_weakness = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'body_weakness')
dizzininess = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'dizzininess')
loss_of_appetite = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'loss_of_appetite')
mp = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'mp')

conclusion = ctrl.Consequent(np.arange(0.1,1.1,0.1),'conclusion')

fever['mild'] = fuzz.trimf(fever.universe,[0,0,0.1])
fever['moderate'] = fuzz.trimf(fever.universe,[0.3,0.4,0.6])
fever['severe'] = fuzz.trimf(fever.universe,[0.5,0.7,0.8])
fever['very serve'] = fuzz.trimf(fever.universe,[0.8,0.95,1.0])

headache['mild'] = fuzz.trimf(headache.universe,[0,0,0.1])
headache['moderate'] = fuzz.trimf(headache.universe,[0.3,0.4,0.6])
headache['severe'] = fuzz.trimf(headache.universe,[0.5,0.7,0.8])
headache['very serve'] = fuzz.trimf(headache.universe,[0.8,0.95,1.0])

nausea['mild'] = fuzz.trimf(nausea.universe,[0,0,0.1])
nausea['moderate'] = fuzz.trimf(nausea.universe,[0.3,0.4,0.6])
nausea['severe'] = fuzz.trimf(nausea.universe,[0.5,0.7,0.8])
nausea['very serve'] = fuzz.trimf(nausea.universe,[0.8,0.95,1.0])

vomiting['mild'] = fuzz.trimf(vomiting.universe,[0,0,0.1])
vomiting['moderate'] = fuzz.trimf(vomiting.universe,[0.3,0.4,0.6])
vomiting['severe'] = fuzz.trimf(vomiting.universe,[0.5,0.7,0.8])
vomiting['very serve'] = fuzz.trimf(vomiting.universe,[0.8,0.95,1.0])

jaundice['mild'] = fuzz.trimf(jaundice.universe,[0,0,0.1])
jaundice['moderate'] = fuzz.trimf(jaundice.universe,[0.3,0.4,0.6])
jaundice['severe'] = fuzz.trimf(jaundice.universe,[0.5,0.7,0.8])
jaundice['very serve'] = fuzz.trimf(jaundice.universe,[0.8,0.95,1.0])

enlarge_liver['mild'] = fuzz.trimf(enlarge_liver.universe,[0,0,0.1])
enlarge_liver['moderate'] = fuzz.trimf(enlarge_liver.universe,[0.3,0.4,0.6])
enlarge_liver['severe'] = fuzz.trimf(enlarge_liver.universe,[0.5,0.7,0.8])
enlarge_liver['very serve'] = fuzz.trimf(enlarge_liver.universe,[0.8,0.9,1.0])

joint_pain['mild'] = fuzz.trimf(joint_pain.universe,[0,0,0.1])
joint_pain['moderate'] = fuzz.trimf(joint_pain.universe,[0.3,0.4,0.6])
joint_pain['severe'] = fuzz.trimf(joint_pain.universe,[0.5,0.7,0.8])
joint_pain['very serve'] = fuzz.trimf(joint_pain.universe,[0.8,0.95,1.0])

body_weakness['mild'] = fuzz.trimf(body_weakness.universe,[0,0,0.1])
body_weakness['moderate'] = fuzz.trimf(body_weakness.universe,[0.3,0.4,0.6])
body_weakness['severe'] = fuzz.trimf(body_weakness.universe,[0.5,0.7,0.8])
body_weakness['very serve'] = fuzz.trimf(body_weakness.universe,[0.8,0.95,1.0])

dizzininess['mild'] = fuzz.trimf(dizzininess.universe,[0,0,0.1])
dizzininess['moderate'] = fuzz.trimf(dizzininess.universe,[0.3,0.4,0.6])
dizzininess['severe'] = fuzz.trimf(dizzininess.universe,[0.5,0.7,0.8])
dizzininess['very serve'] = fuzz.trimf(dizzininess.universe,[0.8,0.95,1.0])

loss_of_appetite['mild'] = fuzz.trimf(loss_of_appetite.universe,[0,0,0.1])
loss_of_appetite['moderate'] = fuzz.trimf(loss_of_appetite.universe,[0.3,0.4,0.6])
loss_of_appetite['severe'] = fuzz.trimf(loss_of_appetite.universe,[0.5,0.7,0.8])
loss_of_appetite['very serve'] = fuzz.trimf(loss_of_appetite.universe,[0.8,0.95,1.0])

conclusion['mild'] = fuzz.trimf(conclusion.universe,[0,0,0.1])
conclusion['moderate'] = fuzz.trimf(conclusion.universe,[0.3,0.4,0.6])
conclusion['severe'] = fuzz.trimf(conclusion.universe,[0.5,0.7,0.8])
conclusion['very serve'] = fuzz.trimf(conclusion.universe,[0.8,0.95,1.0])

mp['mild'] = fuzz.trimf(mp.universe,[0,0,0.1])
mp['moderate'] = fuzz.trimf(mp.universe,[0.3,0.4,0.6])
mp['severe'] = fuzz.trimf(mp.universe,[0.5,0.7,0.8])
mp['very serve'] = fuzz.trimf(mp.universe,[0.8,0.95,1.0])

fever.view()
headache.view()
nausea.view()
vomiting.view()
joint_pain.view()
body_weakness.view()
dizzininess.view()
loss_of_appetite.view()
mp.view()
conclusion.view()
