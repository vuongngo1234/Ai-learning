# %% [markdown]
# <a href="https://colab.research.google.com/github/vuongngo1234/Ai-learning/blob/main/homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

fever = ctrl.Antecedent(np.arange(0.1,1,0.1),'fever')
headache = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'headache')
nausea = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'nausea')
vomiting = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'vomiting')
jaundice = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'jaundice')
enlarge_liver = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'enlarge_liver')
joint_pain = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'joint_pain')
body_weakness = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'body_weakness')
dizzininess = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'dizzininess')
loss_of_appetite = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'loss_of_appetite')
mp = ctrl.Antecedent(np.arange(0.1,1.1,0.1),'mp')

conclusion = ctrl.Consequent(np.arange(0.1,1.1,0.1),'conclusion')

fever['mild'] = fuzz.trimf(fever.universe,[0,0,0.1])
fever['moderate'] = fuzz.trimf(fever.universe,[0.3,0.4,0.6])
fever['severe'] = fuzz.trimf(fever.universe,[0.5,0.7,0.8])
fever['very serve'] = fuzz.trimf(fever.universe,[0.8,0.95,1.0])

headache['mild'] = fuzz.trimf(headache.universe,[0,0,0.1])
headache['moderate'] = fuzz.trimf(headache.universe,[0.3,0.4,0.6])
headache['severe'] = fuzz.trimf(headache.universe,[0.5,0.7,0.8])
headache['very serve'] = fuzz.trimf(headache.universe,[0.8,0.95,1.0])

nausea['mild'] = fuzz.trimf(nausea.universe,[0,0,0.1])
nausea['moderate'] = fuzz.trimf(nausea.universe,[0.3,0.4,0.6])
nausea['severe'] = fuzz.trimf(nausea.universe,[0.5,0.7,0.8])
nausea['very serve'] = fuzz.trimf(nausea.universe,[0.8,0.95,1.0])

vomiting['mild'] = fuzz.trimf(vomiting.universe,[0,0,0.1])
vomiting['moderate'] = fuzz.trimf(vomiting.universe,[0.3,0.4,0.6])
vomiting['severe'] = fuzz.trimf(vomiting.universe,[0.5,0.7,0.8])
vomiting['very serve'] = fuzz.trimf(vomiting.universe,[0.8,0.95,1.0])

jaundice['mild'] = fuzz.trimf(jaundice.universe,[0,0,0.1])
jaundice['moderate'] = fuzz.trimf(jaundice.universe,[0.3,0.4,0.6])
jaundice['severe'] = fuzz.trimf(jaundice.universe,[0.5,0.7,0.8])
jaundice['very serve'] = fuzz.trimf(jaundice.universe,[0.8,0.95,1.0])

enlarge_liver['mild'] = fuzz.trimf(enlarge_liver.universe,[0,0,0.1])
enlarge_liver['moderate'] = fuzz.trimf(enlarge_liver.universe,[0.3,0.4,0.6])
enlarge_liver['severe'] = fuzz.trimf(enlarge_liver.universe,[0.5,0.7,0.8])
enlarge_liver['very serve'] = fuzz.trimf(enlarge_liver.universe,[0.8,0.9,1.0])

joint_pain['mild'] = fuzz.trimf(joint_pain.universe,[0,0,0.1])
joint_pain['moderate'] = fuzz.trimf(joint_pain.universe,[0.3,0.4,0.6])
joint_pain['severe'] = fuzz.trimf(joint_pain.universe,[0.5,0.7,0.8])
joint_pain['very serve'] = fuzz.trimf(joint_pain.universe,[0.8,0.95,1.0])

body_weakness['mild'] = fuzz.trimf(body_weakness.universe,[0,0,0.1])
body_weakness['moderate'] = fuzz.trimf(body_weakness.universe,[0.3,0.4,0.6])
body_weakness['severe'] = fuzz.trimf(body_weakness.universe,[0.5,0.7,0.8])
body_weakness['very serve'] = fuzz.trimf(body_weakness.universe,[0.8,0.95,1.0])

dizzininess['mild'] = fuzz.trimf(dizzininess.universe,[0,0,0.1])
dizzininess['moderate'] = fuzz.trimf(dizzininess.universe,[0.3,0.4,0.6])
dizzininess['severe'] = fuzz.trimf(dizzininess.universe,[0.5,0.7,0.8])
dizzininess['very serve'] = fuzz.trimf(dizzininess.universe,[0.8,0.95,1.0])

loss_of_appetite['mild'] = fuzz.trimf(loss_of_appetite.universe,[0,0,0.1])
loss_of_appetite['moderate'] = fuzz.trimf(loss_of_appetite.universe,[0.3,0.4,0.6])
loss_of_appetite['severe'] = fuzz.trimf(loss_of_appetite.universe,[0.5,0.7,0.8])
loss_of_appetite['very serve'] = fuzz.trimf(loss_of_appetite.universe,[0.8,0.95,1.0])

conclusion['mild'] = fuzz.trimf(conclusion.universe,[0,0,0.1])
conclusion['moderate'] = fuzz.trimf(conclusion.universe,[0.3,0.4,0.6])
conclusion['severe'] = fuzz.trimf(conclusion.universe,[0.5,0.7,0.8])
conclusion['very serve'] = fuzz.trimf(conclusion.universe,[0.8,0.95,1.0])

mp['mild'] = fuzz.trimf(mp.universe,[0,0,0.1])
mp['moderate'] = fuzz.trimf(mp.universe,[0.3,0.4,0.6])
mp['severe'] = fuzz.trimf(mp.universe,[0.5,0.7,0.8])
mp['very serve'] = fuzz.trimf(mp.universe,[0.8,0.95,1.0])

fever.view()
headache.view()
nausea.view()
vomiting.view()
joint_pain.view()
body_weakness.view()
dizzininess.view()
loss_of_appetite.view()
mp.view()
conclusion.view()

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

wind_speed = ctrl.Antecedent(np.arange(0.77,3.222,1),'wind_speed')
temperature = ctrl.Antecedent(np.arange(20.444,41.323,1),'temperature')

rainfall = ctrl.Consequent(np.arange(0.2,9.5,1),'rainfall')

wind_speed['very low WS'] = fuzz.trimf(wind_speed.universe,[0.7,0.7,1.4])
wind_speed['low WS'] = fuzz.trimf(wind_speed.universe,[0.7,1.4,2.5])
wind_speed['normal WS'] = fuzz.trimf(wind_speed.universe,[2.5,2.8,2.9])
wind_speed['high WS'] = fuzz.trimf(wind_speed.universe,[2.8,2.9,3])
wind_speed['very high WS'] = fuzz.trimf(wind_speed.universe,[2.9,3,3.1])

temperature['very low TP'] = fuzz.gaussmf(temperature.universe,20.45,6)
temperature['low TP'] = fuzz.gaussmf(temperature.universe,23.55,6)
temperature['normal TP'] = fuzz.gaussmf(temperature.universe,27.33,6)
temperature['high TP'] = fuzz.gaussmf(temperature.universe,34.75,6)
temperature['very high TP'] = fuzz.gaussmf(temperature.universe,41.3,6)

rainfall['very low RF'] = fuzz.trimf(rainfall.universe,[0.2,0.2,1.5])
rainfall['low RF'] = fuzz.trimf(rainfall.universe,[0.2,1.5,3.5])
rainfall['normal RF'] = fuzz.trimf(rainfall.universe,[1.5,3.5,4.5])
rainfall['high RF'] = fuzz.trimf(rainfall.universe,[3.5,4.5,5.5])
rainfall['very high RF'] = fuzz.trimf(rainfall.universe,[4.5,5.5,9])

wind_speed.view()
temperature.view()
rainfall.view()
rule1 = ctrl.Rule(wind_speed['very low WS']&temperature['very low TP'],rainfall['very low RF'])
rule2 = ctrl.Rule(wind_speed['low WS']&temperature['low TP'],rainfall['very low RF'])
rule3 = ctrl.Rule(wind_speed['very high WS']&temperature['very high TP'],rainfall['very high RF'])
rule4 = ctrl.Rule(wind_speed['high WS']&temperature['very high TP'],rainfall['high RF'])
rule5 = ctrl.Rule(wind_speed['very high WS']&temperature['normal TP'],rainfall['high RF'])
#Cho may hoc
rainfall_ctrl= ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5])
rainfalling = ctrl.ControlSystemSimulation(rainfall_ctrl)

rainfalling.input['wind_speed']=2.5
rainfalling.input['temperature']=26
rainfalling.compute()
print(rainfalling.output['rainfall'])
rainfall.view(sim=rainfalling)
# Out:
# 1.021471730474889

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

taste = ctrl.Antecedent(np.arange(0,11,1),'taste')
environment = ctrl.Antecedent(np.arange(0,11,1),'environment')
budget = ctrl.Antecedent(np.arange(0,10,1),'budget')
location = ctrl.Antecedent(np.arange(0,5,1),'location')
user_review = ctrl.Antecedent(np.arange(0,6,1),'user_review')

preference = ctrl.Consequent(np.arange(0,16,1),'preference')

taste['low'] = fuzz.gaussmf(taste.universe,0,5)
taste['medium'] = fuzz.gaussmf(taste.universe,5,5)
taste['high'] = fuzz.gaussmf(taste.universe,10,5)

environment['low'] = fuzz.gaussmf(environment.universe,0,5)
environment['medium'] = fuzz.gaussmf(environment.universe,5,5)
environment['high'] = fuzz.gaussmf(environment.universe,10,5)

budget['Less Preferred'] = fuzz.gaussmf(budget.universe,9,5)
budget['Preferred'] = fuzz.gaussmf(budget.universe,6,5)
budget['More Preferred'] = fuzz.gaussmf(budget.universe,0,5)

user_review['Less Preferred'] = fuzz.gaussmf(user_review.universe,5,5)
user_review['Preferred'] = fuzz.gaussmf(user_review.universe,3,5)
user_review['More Preferred'] = fuzz.gaussmf(user_review.universe,0,5)

location['Close'] = fuzz.gaussmf(location.universe,0,4)
location['Near'] = fuzz.gaussmf(location.universe,2,4)
location['Far'] = fuzz.gaussmf(location.universe,3,4)
preference['lvl 1'] = fuzz.trimf(preference.universe,[0,0,4])
preference['lvl 2'] = fuzz.trimf(preference.universe,[0,4,6])
preference['lvl 3'] = fuzz.trimf(preference.universe,[4,6,6])
preference['lvl 4'] = fuzz.trimf(preference.universe,[6,8,10])
preference['lvl 5'] = fuzz.trimf(preference.universe,[8,10,12])

taste.view()
environment.view()
budget.view()
user_review.view()
location.view()
preference.view()

rule1 = ctrl.Rule(taste['low']&environment['low']&budget['More Preferred']&location['Far']&user_review['More Preferred'],preference['lvl 1'])
rule2 = ctrl.Rule(taste['low']&environment['medium']&budget['Preferred']&location['Far']&user_review['More Preferred'],preference['lvl 2'])
rule3 = ctrl.Rule(taste['medium']&environment['medium']&budget['More Preferred']&location['Far']&user_review['More Preferred'],preference['lvl 3'])
rule4 = ctrl.Rule(taste['high']&environment['medium']&budget['Preferred']&location['Far']&user_review['Less Preferred'],preference['lvl 4'])
rule5 = ctrl.Rule(taste['high']&environment['high']&budget['Less Preferred']&location['Close']&user_review['Less Preferred'],preference['lvl 5'])

preference_ctrl= ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5])
preferencing = ctrl.ControlSystemSimulation(preference_ctrl)

preferencing.input['taste']=3
preferencing.input['environment']=2
preferencing.input['budget']=2
preferencing.input['location']=3
preferencing.input['user_review']=2
preferencing.compute()
print(preferencing.output['preference'])
preference.view(sim=preferencing)
# Out:
# 4.827742939852868
