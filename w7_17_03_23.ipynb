# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
url = '1.01. Simple linear regression.csv'
data = pd.read_csv(url)
x1 = data.set_index(data['SAT'])
y = data.set_index(data['GPA'])
plt.scatter(x1, y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
data.hist()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7200\4114818476.py in <module>
#       1 import seaborn as sns
# ----> 2 sns.heatmap(correlations, annot=True ) #màu càng đậm giá trị càng thấp
#
# NameError: name 'correlations' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
url = 'mtcars.csv'
data = pd.read_csv(url)
mpg= data['mpg']
disp = data['disp']
hp = data['hp']
wt = data['wt']
data.hist()
plt.show()

# %%
corr = data.corr();
sns.heatmap(corr,annot=True);

# %%
data.plot(kind='scatter', x='wt',y='mpg',figsize=(9,9),color='black');
plt.plot(data['wt'],y_pred,color='blue');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7200\2696218702.py in <module>
#       1 data.plot(kind='scatter', x='wt',y='mpg',figsize=(9,9),color='black');
# ----> 2 plt.plot(data['wt'],y_pred,color='blue');
#
# NameError: name 'y_pred' is not defined

# %%
correlation=data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
pip install scikit-fuzzy
# Out:
# Collecting scikit-fuzzy
#   Downloading scikit-fuzzy-0.4.2.tar.gz (993 kB)
#      ------------------------------------ 994.0/994.0 kB 277.4 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-fuzzy) (1.21.5)
# Requirement already satisfied: scipy>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-fuzzy) (1.9.1)
# Requirement already satisfied: networkx>=1.9.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-fuzzy) (2.8.4)
# Building wheels for collected packages: scikit-fuzzy
#   Building wheel for scikit-fuzzy (setup.py): started
#   Building wheel for scikit-fuzzy (setup.py): finished with status 'done'
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894075 sha256=4cdca8d29ff55a12f8da17e418be4f3e6793b87a2e31470ec2462be5489f058e
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\32\2c\a1\a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import linear_model

# %%
print(regression_model.intercept_)
print(regression_model.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7200\2687751029.py in <module>
# ----> 1 print(regression_model.intercept_)
#       2 print(regression_model.coef_)
#
# NameError: name 'regression_model' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
url = 'mtcars.csv'
data = pd.read_csv(url)
mpg= data['mpg']
disp = data['disp']
hp = data['hp']
wt = data['wt']
data.hist()
plt.show()

# %%
correlation=data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
x=data.drop(data.columns[[2,3]],axis=1)
x
# Out:
#              Unnamed: 0   mpg     wt
# 0             Mazda RX4  21.0  2.620
# 1         Mazda RX4 Wag  21.0  2.875
# 2            Datsun 710  22.8  2.320
# 3        Hornet 4 Drive  21.4  3.215
# 4     Hornet Sportabout  18.7  3.440
# 5               Valiant  18.1  3.460
# 6            Duster 360  14.3  3.570
# 7             Merc 240D  24.4  3.190
# 8              Merc 230  22.8  3.150
# 9              Merc 280  19.2  3.440
# 10            Merc 280C  17.8  3.440
# 11           Merc 450SE  16.4  4.070
# 12           Merc 450SL  17.3  3.730
# 13          Merc 450SLC  15.2  3.780
# 14   Cadillac Fleetwood  10.4  5.250
# 15  Lincoln Continental  10.4  5.424
# 16    Chrysler Imperial  14.7  5.345
# 17             Fiat 128  32.4  2.200
# 18          Honda Civic  30.4  1.615
# 19       Toyota Corolla  33.9  1.835
# 20        Toyota Corona  21.5  2.465
# 21     Dodge Challenger  15.5  3.520
# 22          AMC Javelin  15.2  3.435
# 23           Camaro Z28  13.3  3.840
# 24     Pontiac Firebird  19.2  3.845
# 25            Fiat X1-9  27.3  1.935
# 26        Porsche 914-2  26.0  2.140
# 27         Lotus Europa  30.4  1.513
# 28       Ford Pantera L  15.8  3.170
# 29         Ferrari Dino  19.7  2.770
# 30        Maserati Bora  15.0  3.570
# 31           Volvo 142E  21.4  2.780

# %%
data.plot(kind='scatter', x='wt',y='mpg',figsize=(9,9),color='black');

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7200\912700290.py in <module>
# ----> 1 regressor = LinearRegression()
#       2 regressor.fit(X_train, y_train)
#       3 y_pred = regressor.predict(X_test.round(1))
#       4 calculation = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','predicted Profit'])
#       5 plt.plot(calculation,y_pred,color = 'red');
#
# NameError: name 'LinearRegression' is not defined
